# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as sts
import seaborn as sns
sns.set_style('white')
# %matplotlib inline

# %%
data = pd.read_csv('./Clean/AG_SQ_040814.csv').drop('Unnamed: 0', axis=1)
data
# Out:
#      game_index  move_index       status color  move  \
# 0             0           0  in progress     B    11
# 1             0           1  in progress     W    24
# 2             0           2  in progress     B    21
# 3             0           3  in progress     W    31
# 4             0           4  in progress     B    14
# 5             0           5  in progress     W    33
# 6             0           6  in progress     B    13
# 7             0           7  in progress     W    12
# 8             0           8  in progress     B    29
# 9             0           9  in progress     W     5
# 10            0          10  in progress     B    15
# 11            0          11  in progress     W    16
# 12            0          12  in progress     B    20
# 13            0          13  in progress     W     2
# 14            0          14  in progress     B    22
# 15            0          15  in progress     W    23
# 16            0          16          win     B    19
# ...
