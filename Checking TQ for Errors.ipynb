# %%
import pandas as pd

# %%
dat = pd.read_csv('../../Data/3_lrn/Clean/TQ.csv')
dat.loc[dat.gi==0, :]
# Out:
#       subject  is_comp  color   status                                    bp  \
# 0          21        0      0  playing  000000000000000000000000000000000000
# 1          21        0      0  playing  000000000000100000000000000000000000
# 2          21        0      0  playing  000001000000100000000000000000000000
# 3          21        0      0  playing  000011000000100000000000000000000000
# 4          21        0      0      win  000111000000100000000000000000000000
# 387        21        0      0  playing  000000000000000000000000000000000000
# 388      1019        1      1  playing  000000000000100000000000000000000000
# 389        21        0      0  playing  000000000000100000000000000000000000
# 390      1019        1      1  playing  000000000000110000000000000000000000
# 391        21        0      0  playing  000000000000110000000000000000000000
# 392      1019        1      1  playing  000000000000111000000000000000000000
# ...
