# %%
# Python Standard Libraries
import os

# Python Scientific Libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.stats as sts
import seaborn as sns
import statsmodels
import statsmodels.api as sm
import statsmodels.formula.api as smf

# Project Libraries
import lib.exp4 as exp4
import lib.reconstruction.errors as errs
import lib.reconstruction.features as ftrs
import lib.reconstruction.neighbors as nbrs

import lib.utility_functions as uf
import lib.util.datatype_utilities as dtutils

# Config
sns.set_style('white')
sns.set_context('paper')

pd.set_option('display.max_columns', 40)

% matplotlib inline

# %%
colors = sns.cubehelix_palette(n_colors=2, start=0.5, hue=1, rot=.1, light=.65) 
colors += sns.cubehelix_palette(n_colors=2, start=2.5, hue=1, rot=.1, light=.65)
sns.palplot(colors)

# %%
colors = dict(zip(['real', 'fake', 'trained', 'untrained'], colors))

# %%
tidy = pd.read_csv('./tidy_data.csv', index_col=0)
tidy['Condition'] = tidy['Condition'].map(lambda x: 'Untrained' if x == 'Naive' else x)
tidy['Position ID'] = tidy['Position ID'].map(int)
tidy['Num Dif'] = tidy['Num Pieces (final)'] - tidy['Num Pieces']

vals = ['Black Position', 'White Position', 'Is Real', 'Num Pieces']

board_set = tidy.pivot_table(index='Position ID', values=vals, aggfunc=lambda x: x.unique()[0])[vals]

# %%
mean_piv = tidy.pivot_table(
    index='Subject ID', values='Total Errors', columns=['Is Real', 'Num Pieces']
)

mean_piv['Condition'] = mean_piv.index.map(lambda x: tidy.loc[tidy['Subject ID'] == x, 'Condition'].values[0])

std_piv = tidy.pivot_table(
    index='Subject ID', values='Total Errors', columns=['Is Real', 'Num Pieces'],
    aggfunc=np.std
)

std_piv['Condition'] = mean_piv.index.map(lambda x: tidy.loc[tidy['Subject ID'] == x, 'Condition'].values[0])

# %%
tidy['x'] = tidy['Num Pieces']
# tidy['y'] = tidy['Type II Errors']

tidy['y'] = tidy['Type I Errors'] / (36 - tidy['Num Pieces'])
# tidy['y'] = tidy['Type II Errors'] / tidy['Num Pieces']
# tidy['y'] = tidy['Type III Errors'] / tidy['Num Pieces']

# %%
c_filter = mean_piv['Condition'] == 'Trained'

# %%
fig, axes = plt.subplots(1, 2, figsize=(8, 3), dpi=300)

tc_filter = tidy['Condition'] == 'Trained'
tp_filter = tidy['Is Real'] == True


def errbar_plot(df, ax, **kwargs):
    piv = df.pivot_table(
        index='Subject ID', values='y', columns='Num Pieces'
    )
    
    x = piv.columns.values
    y = piv.mean(axis=0)
    err = piv.std() / np.sqrt(len(piv))

    ax.errorbar(x, y, yerr=err, **kwargs)
    
    return None


## Real

ax = axes[0]

#### Trained

errbar_plot(
    tidy.loc[tc_filter & tp_filter], 
    ax=ax, color=colors['trained'], alpha=.9, label='Trained'
)

#### Untrained

errbar_plot(
    tidy.loc[~tc_filter & tp_filter],
    ax=ax, color=colors['untrained'], alpha=.9, label='Untrained'
)


## Fake

ax = axes[1]

#### Trained

errbar_plot(
    tidy.loc[tc_filter & ~tp_filter], 
    ax=ax, color=colors['trained'], alpha=.9, label='Trained'
)

#### Untrained

errbar_plot(
    tidy.loc[~tc_filter & ~tp_filter],
    ax=ax, color=colors['untrained'], alpha=.9, label='Untrained'
)

## Make it fancy

# axes[0].plot(np.arange(20), color='grey')
# axes[1].plot(np.arange(20), color='grey')

axes[0].legend(loc=2)

plt.setp(
    axes, 
    ylabel='Error Rate', xlabel='# Pieces', 
    xlim=[9, 20], 
    ylim=[0, .5]
#     ylim=[0, 12],
#     xticks=np.arange(11, 19, 1), xticklabels=np.arange(11, 19, 1),
#     yticks=np.arange(9, 20, 1), yticklabels=np.arange(9, 20, 1)
)
plt.setp(axes[0], title='Real Positions')
plt.setp(axes[1], title='Fake Positions')

sns.despine()
plt.tight_layout()

# %%
fig, axes = plt.subplots(1, 2, figsize=(8, 3), dpi=300)

tc_filter = tidy['Condition'] == 'Trained'
tp_filter = tidy['Is Real'] == True


def errbar_plot(df, ax, **kwargs):
    piv = df.pivot_table(
        index='Subject ID', values='y', columns='Num Pieces'
    )
    
    x = piv.columns.values
    y = piv.mean(axis=0)
    err = piv.std() / np.sqrt(len(piv))

    ax.errorbar(x, y, yerr=err, **kwargs)
    
    return None


## Trained

ax = axes[0]

#### Real

errbar_plot(
    tidy.loc[tc_filter & tp_filter], 
    ax=ax, color=colors['real'], alpha=.9, label='Real'
)

#### Fake

errbar_plot(
    tidy.loc[tc_filter & ~tp_filter],
    ax=ax, color=colors['fake'], alpha=.9, label='Fake'
)


## Untrained

ax = axes[1]

#### Trained

errbar_plot(
    tidy.loc[~tc_filter & tp_filter], 
    ax=ax, color=colors['real'], alpha=.9, label='Real'
)

#### Untrained

errbar_plot(
    tidy.loc[~tc_filter & ~tp_filter],
    ax=ax, color=colors['fake'], alpha=.9, label='Fake'
)

## Make it fancy

# axes[0].plot(np.arange(20), color='grey')
# axes[1].plot(np.arange(20), color='grey')

axes[0].legend(loc=2)

plt.setp(
    axes, 
    ylabel='Error Rate', xlabel='Original # Pieces', 
    xlim=[9, 20], 
    ylim=[0, .5]
#     ylim=[0, 12],
#     xticks=np.arange(11, 19, 1), xticklabels=np.arange(11, 19, 1),
#     yticks=np.arange(9, 20, 1), yticklabels=np.arange(9, 20, 1)
)
plt.setp(axes[0], title='Trained Subjects')
plt.setp(axes[1], title='Untrained')

sns.despine()
plt.tight_layout()

# %%
tidy.head()
# Out:
#       Subject ID Condition  Game Index  Position ID  Is Real  \
# 0  1464109333721   Trained           0           25    False
# 2  1464109333721   Trained           1           92     True
# 4  1464109333721   Trained           2           16    False
# 6  1464109333721   Trained           3           75     True
# 8  1464109333721   Trained           4           69     True
#
#                          Black Position                        White Position  \
# 0  000000000011010000010100000001010001  001100000000001000001000000010100010
# 2  001011000000011000000101000000010100  000100000001100100000010100001101000
# 4  100100000001010000000100000000101000  000010000010000100001001000001000000
# 6  000001001000101100001001000000010000  000100000001010000010110000000001000
# 8  000101000101100000001100000000000000  000000000010011000000001000000111000
#
#                  Black Position (final)                White Position (final)  \
# 0  000000000011010000010100100001000000  000100000000100010001011000000000100
# 2  000001000001011000000101000000010100  000100000000100100001010100000101000
# 4  100100000001010000000101000000100000  000001000010000100001000000000000000
# 6  000001001001001100000101000000010000  000100000000110000000010000000001000
# 8  000101000101100000001100000000000000  000000000010011000000001000000111000
#
#    Response Time  Num Black Pieces  Num White Pieces  Num Pieces  \
# 0         43.957                 8                 7          15
# 2         36.897                 9                 9          18
# 4         17.922                 7                 6          13
# 6         22.380                 8                 7          15
# 8         20.494                 7                 7          14
#
#    Total Black Errors  Total White Errors  Total Errors  \
# 0                   3                  10          13.0
# 2                   3                   3           5.0
# 4                   2                   4           5.0
# 6                   4                   4           5.0
# 8                   0                   0           0.0
#
#    Type I Errors (black)  Type I Errors (white)  Type I Errors  \
# 0                      1                      5              6
# 2                      0                      1              1
# 4                      0                      1              1
# 6                      0                      0              0
# 8                      0                      0              0
#
#    Type II Errors (black)  Type II Errors (white)  Type II Errors  \
# 0                       2                       5               7
# 2                       2                       1               3
# 4                       1                       2               3
# 6                       1                       1               2
# 8                       0                       0               0
#
#    Type III Errors (black)  Type III Errors (white)  Type III Errors  \
# 0                        0                        0                0
# 2                        0                        1                1
# 4                        0                        1                1
# 6                        1                        2                3
# 8                        0                        0                0
#
#    Num Pieces (final)  Numerosity Error  Num Dif   x         y        y2
# 0                  14                 1       -1  15  0.285714  0.466667
# 2                  16                 2       -2  18  0.055556  0.166667
# 4                  11                 2       -2  13  0.043478  0.230769
# 6                  13                 2       -2  15  0.000000  0.133333
# 8                  14                 0        0  14  0.000000  0.000000

# %% [markdown]
# # Negative Binomial Regression

# %%
NBFam = sm.families.NegativeBinomial()

class PerSubjectNBRRegress(object):
    def get_fitted_model(self, data):
        glm = smf.glm(formula='y ~ x', data=data, family=NBFam)
        return glm.fit(method='bfgs', maxiter=10000)
        
    def __call__(self, condition='Trained', is_real=True):
        support = np.arange(0, 20, .2)

        models = []
        c = tidy['Condition'] == condition
        r = tidy['Is Real'] == is_real

        T = tidy.loc[c & r]

        for subject_id in T['Subject ID'].unique():
            p = T['Subject ID'] == subject_id
            S = T.loc[p]

            model = self.get_fitted_model(data=S)
            models.append(model)

        params = pd.DataFrame([m.params for m in models], index=T['Subject ID'].unique())
        params['prediction'] = [m.predict(exog=np.stack([support, np.ones_like(support)]).T) for m in models]
        params['Condition'] = condition
        params['Is Real'] = is_real

        return params, models
        

class PerSubjectLogisticRegress(PerSubjectNBRRegress):
    def get_fitted_model(self, data):
        x = data['x']
        x_intercept = np.ones_like(x)
        x = np.stack([x, x_intercept]).T
        y = data['y']
        
        model = sm.Logit(y, x)
        return model.fit()


nbr_regress = PerSubjectNBRRegress()
logistic_regress = PerSubjectLogisticRegress()

# %%
param_dfs = []
models_list = []

for condition in ['Trained', 'Untrained']:
    for is_real in [True, False]:
        param_df, models = logistic_regress(condition=condition, is_real=is_real)
        param_dfs.append(param_df)
        models_list.append(models)
        
        
params = pd.concat(param_dfs)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.047136
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.012060
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.094341
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.107073
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.047275
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.008252
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.055610
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.315627
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.074581
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.095810
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.069346
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.055768
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.052060
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.046033
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.102383
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.051480
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.023745
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.074095
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.194580
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.120201
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.051114
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.150171
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.150405
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.084655
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.021966
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.127841
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.427753
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.160801
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.176150
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.175192
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.117102
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.127751
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.059944
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.217754
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.078241
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.073395
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.149599
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.379260
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.029215
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.074025
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.105567
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.042319
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.145553
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.139651
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.039179
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.048070
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.103518
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.053413
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.054609
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.075823
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.056839
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.070515
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.070413
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.107561
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.102660
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.053456
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.006181
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.105593
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.113760
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.181806
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.064308
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.200613
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.207940
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.107325
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.123769
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.242320
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.087555
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.124547
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.113214
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.130066
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.156984
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.139458
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.204831
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.163389
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.090095
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.015529
#          Iterations 9

# %%
fig, axes = plt.subplots(1, 2, figsize=(8, 3), dpi=300)

params_condition_filter = params['Condition'] == 'Trained'
params_position_filter = params['Is Real']

support = np.arange(0, 20, .2)

def get_fitted_lines(p):
    for i, row in enumerate(p.iterrows()):
#         x = row[1]['x']
#         b = row[1]['Intercept']
        x = row[1]['x1']
        b = 0
        
#         model = models_list[i][]
#         fit = model.predict(params=x, exog=support)
#         fit = np.exp(x * support + b)
#         fit = 1 / (1 + np.exp(x * support))
        fit = row[1]['prediction']
        
        yield fit        

# Trained 

ax = axes[0]

### Real

p = params.loc[params_condition_filter & params_position_filter]
base = np.zeros_like(support)

for l in get_fitted_lines(p):
    ax.plot(support, l, color=colors['real'], alpha=.2)
    base += l
    
mean = base / len(p)

ax.plot(support, mean, color=colors['real'], linewidth=4, label='Real')
    
### Fake

p = params.loc[params_condition_filter & ~params_position_filter]
base = np.zeros_like(support)

for l in get_fitted_lines(p):
    ax.plot(support, l, color=colors['fake'], alpha=.2)
    base += l
    
mean = base / len(p)

ax.plot(support, mean, color=colors['fake'], linewidth=4, label='Fake')


# Untrained 

ax = axes[1]

### Real

p = params.loc[~params_condition_filter & params_position_filter]
base = np.zeros_like(support)

for l in get_fitted_lines(p):
    ax.plot(support, l, color=colors['real'], alpha=.2)
    base += l
    
mean = base / len(p)

ax.plot(support, mean, color=colors['real'], linewidth=4)
    
### Fake

p = params.loc[~params_condition_filter & ~params_position_filter]
base = np.zeros_like(support)

for l in get_fitted_lines(p):
    ax.plot(support, l, color=colors['fake'], alpha=.2)
    base += l
    
mean = base / len(p)

ax.plot(support, mean, color=colors['fake'], linewidth=4)
    

    
sns.despine()

axes[0].legend(loc=0)

plt.setp(
    axes, 
    ylabel='Error Rate', xlabel='Original # Pieces', 
#     xlim=[9, 20], ylim=[0, 12],
    xlim=[10, 19], ylim=[0, .6],
    xticks=np.arange(11, 19, 1), xticklabels=np.arange(11, 19, 1),
#     yticks=np.arange(9, 20, 1), yticklabels=np.arange(9, 20, 1)
)
plt.setp(axes[0], title='Trained Subjects')
plt.setp(axes[1], title='Untrained')

sns.despine()
plt.tight_layout()

# %%
idx_names = ['Trained', 'Untrained']
col_names = [False, True]

outputs = pd.DataFrame(index=idx_names, columns=col_names)
outputs.columns.name = 'MEAN CORRCOEF'


for idx in idx_names:
    for col in col_names:
        f_idx = tidy['Condition'] == idx
        f_col = tidy['Is Real'] == col
        g = tidy.loc[f_idx & f_col].groupby('Subject ID')
        outputs.loc[idx, col] = g.apply(
            lambda g_: np.corrcoef(g_['Num Pieces'].values, g_['y2'].values)[0, 1]
        ).mean()

outputs
# Out:
# MEAN CORRCOEF     False     True
# Trained        0.379886  0.400345
# Untrained      0.438934  0.393803

# %%
idx_names = ['Trained', 'Untrained']
col_names = [False, True]

outputs = pd.DataFrame(index=idx_names, columns=col_names)
outputs.columns.name = 'SEM CORRCOEF'


for idx in idx_names:
    for col in col_names:
        f_idx = tidy['Condition'] == idx
        f_col = tidy['Is Real'] == col
        g = tidy.loc[f_idx & f_col].groupby('Subject ID')
        corcoefs = g.apply(lambda g_: np.corrcoef(g_['Num Pieces'].values, g_['y2'].values)[0, 1])
        outputs.loc[idx, col] = corcoefs.std() / np.sqrt(len(corcoefs))
outputs
# Out:
# SEM CORRCOEF      False      True
# Trained       0.0355171  0.0338075
# Untrained      0.034224  0.0293095

# %%
val = 'const'

# %%
means = params.pivot_table(index='Condition', values=val, columns='Is Real', aggfunc=np.mean)
sems = params.pivot_table(index='Condition', values=val, columns='Is Real', aggfunc=lambda x: x.std() / np.sqrt(len(x)))

# %%
means.columns.name = 'MEANS'
means.index.name = None
means
# Out:
# MEANS         False     True
# Trained   -4.093142 -4.864180
# Untrained -4.353508 -5.123463

# %%
sems.columns.name = 'SEMS'
sems.index.name = None
sems
# Out:
# SEMS          False     True
# Trained    0.186654  0.428862
# Untrained  0.306542  0.541281

# %%
fig, axes = plt.subplots(1, 2, figsize=(8, 3), dpi=300)

axes[0].bar([0], means.loc['Trained', True], color=colors['trained'], label='Trained')
axes[0].bar([1], means.loc['Untrained', True], color=colors['untrained'], label='Untrained')
axes[0].errorbar([0], means.loc['Trained', True], yerr=sems.loc['Trained', True], color='black')
axes[0].errorbar([1], means.loc['Untrained', True], yerr=sems.loc['Untrained', True], color='black')

axes[1].bar([0], means.loc['Trained', False], color=colors['trained'])
axes[1].bar([1], means.loc['Untrained', False], color=colors['untrained'])
axes[1].errorbar([0], means.loc['Trained', False], yerr=sems.loc['Trained', False], color='black')
axes[1].errorbar([1], means.loc['Untrained', False], yerr=sems.loc['Untrained', False], color='black')

plt.figlegend(loc=(.85, .15))

plt.setp(
    axes,
#     ylim=[0, .25], 
    ylim=[-5, 0],
    ylabel=r'$\mathit{\beta_0}$',
    xticks=[0, 1], xticklabels=['Trained', 'Untrained']
)

plt.setp(axes[0], title='Real Positions')
plt.setp(axes[1], title='Fake Positions')

sns.despine()
plt.tight_layout()

# %%
c = params['Condition'] == 'Trained'
r = params['Is Real'] == True

# %%
pvalues = params.pivot_table(
    index='Condition', values=val, columns='Is Real', 
    aggfunc=lambda x: sts.ttest_1samp(x, 0).pvalue
)

pvalues.columns.name = 'PVALUES'
pvalues.index.name = None
pvalues
# Out:
# PVALUES           False         True
# Trained    1.954010e-14  1.244062e-09
# Untrained  3.205990e-11  2.065835e-08

# %%
results = pd.DataFrame()

results.loc['Condition', 'True'] = sts.ttest_ind(params.loc[c & r, val].values, params.loc[~c & r, val].values).pvalue
results.loc['Condition', 'False'] = sts.ttest_ind(params.loc[c & ~r, val].values, params.loc[~c & ~r, val].values).pvalue

results.loc['Position Type', 'Trained'] = sts.ttest_ind(params.loc[c & r, val].values, params.loc[c & ~r, val].values).pvalue
results.loc['Position Type', 'Untrained'] = sts.ttest_ind(params.loc[~c & r, val].values, params.loc[~c & ~r, val].values).pvalue

# %%
results.columns.name = 'PVALUES\tConstant'
results.index.name = 'Variable'
results
# Out:
# PVALUES	Constant      True    False   Trained  Untrained
# Variable
# Condition         0.709526  0.47286       NaN        NaN
# Position Type          NaN      NaN  0.107951   0.223817
